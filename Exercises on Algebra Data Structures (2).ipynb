# %%
import numpy as np

# Misalkan nilai s (contoh: s = 1)
s = 1

# Buat vector (kolom)
v = np.array([[25],
              [2],
              [-3],
              [-23]])

print("Vector awal:")
print(v)

# Transpose vector
v_T = v.T

print("\nTranspose vector:")
print(v_T)
# Out:
# Vector awal:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
#
# Transpose vector:
# [[ 25   2  -3 -23]]
