# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([17, 1, 60]) # type argument is optional, e.g.: dtype=np.float16
x
# Out:
# array([17,  1, 60])

# %%
# hitung panjang vector x
len(x)
# Out:
# 3

# %%
# tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
# tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
# akses elemen pertama dari vector x
x[0] # zero-indexed
# Out:
# np.int64(17)

# %%
# tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# Vektor Transpose

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([17,  1, 60])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[17, 1, 60]])
y
# Out:
# array([[17,  1, 60]])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %% [markdown]
# Pytorch dan Tensorflow

# %%
import torch
import tensorflow as tf

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_pt = torch.tensor([17, 1, 60])
x_pt
# Out:
# tensor([17,  1, 60])

# %%
# tampilkan ukuran dari vector x_t
x_tf = tf.Variable([17, 1, 60])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([17,  1, 60], dtype=int32)>
